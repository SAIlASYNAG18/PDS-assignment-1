# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from plotly.tools import FigureFactory as FF
rawdata=pd.read_csv('/content/work.csv')
rawdata
# Out:
#    Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
# 5    68.7     123   50             26       N
# 6    69.8     141   51             22       Y
# 7    70.1     136   23             20       Y
# 8    67.9     112   17             19       N
# 9    66.8     120   39             31       N

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x='Frailty', y='Grip strength', data=clean_data, palette='Set2')
plt.xlabel('Frailty')
plt.ylabel('Grip Strength')
plt.title('Box Plot of Grip Strength by Frailty')
plt.show()
# Out:
# <ipython-input-28-58f7756aa800>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.boxplot(x = rawdata['Frailty'], y = rawdata['Grip strength'])
# Out:
# <Axes: xlabel='Frailty', ylabel='Grip strength'>
